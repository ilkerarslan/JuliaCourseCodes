# %%
i = 1;

while i < 5
    println(i^2)
    global i += 1   # i = i + 1
end

# %%
arr = [3, 5, 7, 9, 11, 13, 15]

while !isempty(arr)
    print(pop!(arr), " ")
end

# %%
file = open("inputFile.txt", "r")
line = readline(file)
while line != ""
    println(line)
    line = readline(file)
end
close(file)
